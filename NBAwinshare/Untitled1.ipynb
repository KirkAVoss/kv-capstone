# %%
from source import seasonalregressor
from source import data_wrangle
import matplotlib.pyplot as plt
import pandas as pd
from pandas.plotting import scatter_matrix
import numpy as np
import seaborn as sb
from sklearn.ensemble import RandomForestRegressor
# %matplotlib inline

# %%
advanced = data_wrangle.read_all_advanced('./data/advanced')
pergame  = data_wrangle.read_all_pergame('./data/per_game')
seasonal = data_wrangle.clean_and_join_seasonal_dataframe(advanced, pergame)
demographic = data_wrangle.read_demographic_data('./data/player_data.csv')
fullstats = data_wrangle.add_years_in_league(seasonal, demographic)

# %%
fullstats.head()
# Out:
#        Player Pos  Age   Tm   G  MP_total   PER    TS%   3PAr    FTr  \
# 0  A.C. Green  PF   33  TOT  83      2492  12.4  0.523  0.041  0.407
# 1  A.C. Green  PF   34  DAL  82      2649  12.8  0.496  0.007  0.303
# 2  A.C. Green  PF   35  DAL  50       924  12.5  0.441  0.031  0.203
# 3  A.C. Green  PF   36  LAL  82      1929  11.2  0.482  0.010  0.245
# 4  A.C. Green  PF   37  MIA  82      1411  11.2  0.492  0.019  0.343
#
#         ...        ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PS/G  \
# 0       ...        2.7  5.2  7.9  0.8  0.8  0.2  0.9  1.7   7.2
# 1       ...        2.7  5.5  8.1  1.5  1.0  0.3  0.8  1.9   7.3
# 2       ...        1.6  2.9  4.6  0.5  0.6  0.2  0.4  1.4   4.9
# 3       ...        2.0  4.0  5.9  1.0  0.6  0.2  0.6  1.5   5.0
# 4       ...        1.3  2.5  3.8  0.5  0.4  0.1  0.5  1.5   4.5
#
#    Seasons_number
# 0              12
# 1              13
# 2              14
# 3              15
# 4              16
#
# [5 rows x 53 columns]

# %%
player = "A.C. Green"
player = "LeBron James"


seasons_needed = {1, 2, 3, 4}
seasons_one_thru_four = {1, 2, 3, 4}
season_to_predict = 5
seasons_needed.add(season_to_predict)

#demographic[demographic['name']==player]['year_start'] == 2015).bool()

count = 0
fullfive = []
notfive = {}
fourbutnotfive_but_not_from2015 = {}
missing_something_from_years_1thru4_but_has_5 ={}
for player in fullstats['Player'].unique():
    playerset = set(fullstats.loc[fullstats['Player']==player, 'Seasons_number'])
    if seasons_needed.issubset(playerset):
        print("Have five full-year stats ",player)
        fullfive.append(player)
        count += 1
    elif seasons_one_thru_four.issubset(playerset) and not (demographic[demographic['name']==player]['year_start'] == 2015).bool():
        fourbutnotfive_but_not_from2015[player] = playerset
    elif 5 in playerset and (demographic[demographic['name']==player]['year_start'] > 1997).bool():
        missing_something_from_years_1thru4_but_has_5[player] = playerset
    else:
        notfive[player] = playerset

print("Number:",count)
# Out:
# Have five full-year stats  A.J. Price
# Have five full-year stats  Aaron Gray
# Have five full-year stats  Adonal Foyle
# Have five full-year stats  Adrian Griffin
# Have five full-year stats  Al Harrington
# Have five full-year stats  Al Horford
# Have five full-year stats  Al Jefferson
# Have five full-year stats  Al-Farouq Aminu
# Have five full-year stats  Alec Burks
# Have five full-year stats  Alex Len
# Have five full-year stats  Allen Crabbe
# Have five full-year stats  Allen Iverson
# Have five full-year stats  Alonzo Gee
# Have five full-year stats  Alvin Williams
# Have five full-year stats  Amar'e Stoudemire
# Have five full-year stats  Amir Johnson
# Have five full-year stats  Anderson Varejao
# Have five full-year stats  Andray Blatche
# Have five full-year stats  Andre Drummond
# Have five full-year stats  Andre Iguodala
# Have five full-year stats  Andre Miller
# Have five full-year stats  Andre Roberson
# Have five full-year stats  Andrea Bargnani
# Have five full-year stats  Andrei Kirilenko
# Have five full-year stats  Andres Nocioni
# Have five full-year stats  Andrew Bogut
# Have five full-year stats  Andrew Bynum
# Have five full-year stats  Andrew Nicholson
# Have five full-year stats  Andris Biedrins
# Have five full-year stats  Antawn Jamison
# Have five full-year stats  Anthony Carter
# Have five full-year stats  Anthony Davis
# Have five full-year stats  Anthony Johnson
# Have five full-year stats  Anthony Morrow
# Have five full-year stats  Anthony Randolph
# Have five full-year stats  Anthony Tolliver
# Have five full-year stats  Antoine Walker
# Have five full-year stats  Antoine Wright
# Have five full-year stats  Antonio Daniels
# Have five full-year stats  Aron Baynes
# Have five full-year stats  Arron Afflalo
# Have five full-year stats  Austin Croshere
# Have five full-year stats  Austin Daye
# Have five full-year stats  Austin Rivers
# Have five full-year stats  Avery Bradley
# Have five full-year stats  Baron Davis
# Have five full-year stats  Ben Gordon
# Have five full-year stats  Ben McLemore
# Have five full-year stats  Ben Wallace
# Have five full-year stats  Beno Udrih
# Have five full-year stats  Bismack Biyombo
# Have five full-year stats  Blake Griffin
# Have five full-year stats  Bobby Jackson
# Have five full-year stats  Bobby Simmons
# Have five full-year stats  Bonzi Wells
# Have five full-year stats  Boris Diaw
# Have five full-year stats  Bostjan Nachbar
# Have five full-year stats  Brad Miller
# Have five full-year stats  Bradley Beal
# Have five full-year stats  Brandon Bass
# Have five full-year stats  Brandon Jennings
# Have five full-year stats  Brandon Knight
# Have five full-year stats  Brandon Roy
# Have five full-year stats  Brandon Rush
# Have five full-year stats  Brendan Haywood
# Have five full-year stats  Brevin Knight
# Have five full-year stats  Brian Cardinal
# Have five full-year stats  Brian Cook
# Have five full-year stats  Brian Roberts
# Have five full-year stats  Brian Scalabrine
# Have five full-year stats  Brian Skinner
# Have five full-year stats  Brook Lopez
# Have five full-year stats  Bruce Bowen
# Have five full-year stats  Bruno Sundov
# Have five full-year stats  Bryce Drew
# Have five full-year stats  Byron Mullens
# Have five full-year stats  C.J. Miles
# Have five full-year stats  C.J. Watson
# Have five full-year stats  CJ McCollum
# Have five full-year stats  Calvin Booth
# Have five full-year stats  Carl Landry
# Have five full-year stats  Carlos Arroyo
# Have five full-year stats  Carlos Boozer
# Have five full-year stats  Carmelo Anthony
# Have five full-year stats  Caron Butler
# Have five full-year stats  Cartier Martin
# Have five full-year stats  Cedric Henderson
# Have five full-year stats  Chandler Parsons
# Have five full-year stats  Channing Frye
# Have five full-year stats  Charlie Villanueva
# Have five full-year stats  Chase Budinger
# Have five full-year stats  Chauncey Billups
# Have five full-year stats  Chris Andersen
# Have five full-year stats  Chris Bosh
# Have five full-year stats  Chris Crawford
# Have five full-year stats  Chris Duhon
# Have five full-year stats  Chris Kaman
# Have five full-year stats  Chris Mihm
# Have five full-year stats  Chris Paul
# Have five full-year stats  Chris Quinn
# Have five full-year stats  Chris Wilcox
# Have five full-year stats  Chuck Hayes
# Have five full-year stats  Chucky Atkins
# Have five full-year stats  Cody Zeller
# Have five full-year stats  Cole Aldrich
# Have five full-year stats  Corey Brewer
# Have five full-year stats  Corey Maggette
# Have five full-year stats  Cory Joseph
# Have five full-year stats  Courtney Lee
# Have five full-year stats  Craig Smith
# Have five full-year stats  Cuttino Mobley
# Have five full-year stats  D.J. Augustin
# Have five full-year stats  D.J. White
# Have five full-year stats  Daequan Cook
# Have five full-year stats  Dahntay Jones
# Have five full-year stats  Damian Lillard
# Have five full-year stats  Damien Wilkins
# Have five full-year stats  Damon Jones
# Have five full-year stats  Dan Dickau
# Have five full-year stats  Dan Gadzuric
# Have five full-year stats  Daniel Gibson
# Have five full-year stats  Danilo Gallinari
# Have five full-year stats  Danny Fortson
# Have five full-year stats  Danny Granger
# Have five full-year stats  Danny Green
# Have five full-year stats  Dante Cunningham
# Have five full-year stats  Darius Miles
# Have five full-year stats  Darius Songaila
# Have five full-year stats  Darko Milicic
# Have five full-year stats  Darren Collison
# Have five full-year stats  David Lee
# Have five full-year stats  David West
# Have five full-year stats  DeAndre Jordan
# Have five full-year stats  DeJuan Blair
# Have five full-year stats  DeMar DeRozan
# Have five full-year stats  DeMarcus Cousins
# Have five full-year stats  DeMarre Carroll
# Have five full-year stats  DeSagana Diop
# Have five full-year stats  DeShawn Stevenson
# Have five full-year stats  Dean Garrett
# Have five full-year stats  Delonte West
# Have five full-year stats  Dennis Schroder
# Have five full-year stats  Derek Anderson
# Have five full-year stats  Derek Fisher
# Have five full-year stats  Deron Williams
# Have five full-year stats  Derrick Favors
# Have five full-year stats  Derrick Williams
# Have five full-year stats  Desmond Mason
# Have five full-year stats  Devean George
# Have five full-year stats  Devin Brown
# Have five full-year stats  Devin Harris
# Have five full-year stats  Dewayne Dedmon
# Have five full-year stats  Didier Ilunga-Mbenga
# Have five full-year stats  Dion Glover
# Have five full-year stats  Dion Waiters
# Have five full-year stats  Dirk Nowitzki
# Have five full-year stats  Dominic McGuire
# Have five full-year stats  Donald Sloan
# Have five full-year stats  Donatas Motiejunas
# Have five full-year stats  Donnell Harvey
# Have five full-year stats  Dorell Wright
# Have five full-year stats  Draymond Green
# Have five full-year stats  Drew Gooden
# Have five full-year stats  Dwayne Jones
# Have five full-year stats  Dwight Howard
# Have five full-year stats  Dwyane Wade
# Have five full-year stats  E'Twaun Moore
# Have five full-year stats  Earl Boykins
# Have five full-year stats  Earl Clark
# Have five full-year stats  Earl Watson
# Have five full-year stats  Ed Davis
# Have five full-year stats  Eddie House
# Have five full-year stats  Eddie Robinson
# Have five full-year stats  Eddy Curry
# Have five full-year stats  Eduardo Najera
# Have five full-year stats  Ekpe Udoh
# Have five full-year stats  Elton Brand
# Have five full-year stats  Emeka Okafor
# Have five full-year stats  Enes Kanter
# Have five full-year stats  Eric Bledsoe
# Have five full-year stats  Eric Gordon
# Have five full-year stats  Eric Maynor
# Have five full-year stats  Erick Dampier
# Have five full-year stats  Erick Strickland
# Have five full-year stats  Etan Thomas
# Have five full-year stats  Evan Fournier
# Have five full-year stats  Evan Turner
# Have five full-year stats  Fabricio Oberto
# Have five full-year stats  Francisco Elson
# Have five full-year stats  Francisco Garcia
# Have five full-year stats  Fred Jones
# Have five full-year stats  Gary Neal
# Have five full-year stats  George Hill
# Have five full-year stats  Gerald Henderson
# Have five full-year stats  Gerald Wallace
# Have five full-year stats  Giannis Antetokounmpo
# Have five full-year stats  Gilbert Arenas
# Have five full-year stats  Glen Davis
# Have five full-year stats  Goran Dragic
# Have five full-year stats  Gordan Giricek
# Have five full-year stats  Gordon Hayward
# Have five full-year stats  Gorgui Dieng
# Have five full-year stats  Greg Buckner
# Have five full-year stats  Greg Monroe
# Have five full-year stats  Greg Smith
# Have five full-year stats  Greivis Vasquez
# Have five full-year stats  Hakim Warrick
# Have five full-year stats  Hamed Haddadi
# Have five full-year stats  Harrison Barnes
# Have five full-year stats  Hasheem Thabeet
# Have five full-year stats  Hedo Turkoglu
# Have five full-year stats  Hilton Armstrong
# Have five full-year stats  Ian Clark
# Have five full-year stats  Iman Shumpert
# Have five full-year stats  Ira Newble
# Have five full-year stats  Isaiah Canaan
# Have five full-year stats  Isaiah Thomas
# Have five full-year stats  Ish Smith
# Have five full-year stats  J.J. Barea
# Have five full-year stats  J.J. Hickson
# Have five full-year stats  J.J. Redick
# Have five full-year stats  J.R. Smith
# Have five full-year stats  JaVale McGee
# Have five full-year stats  Jacque Vaughn
# Have five full-year stats  Jae Crowder
# Have five full-year stats  Jahidi White
# Have five full-year stats  Jake Tsakalidis
# Have five full-year stats  Jake Voskuhl
# Have five full-year stats  Jamaal Magloire
# Have five full-year stats  Jamaal Tinsley
# Have five full-year stats  Jamal Crawford
# Have five full-year stats  Jamal Sampson
# Have five full-year stats  Jamario Moon
# Have five full-year stats  Jameer Nelson
# Have five full-year stats  James Harden
# Have five full-year stats  James Johnson
# Have five full-year stats  James Jones
# Have five full-year stats  James Posey
# Have five full-year stats  Jamie Feick
# Have five full-year stats  Jannero Pargo
# Have five full-year stats  Jared Dudley
# Have five full-year stats  Jared Jeffries
# Have five full-year stats  Jared Sullinger
# Have five full-year stats  Jarrett Jack
# Have five full-year stats  Jarron Collins
# Have five full-year stats  Jarvis Hayes
# Have five full-year stats  Jason Collier
# Have five full-year stats  Jason Collins
# Have five full-year stats  Jason Kapono
# Have five full-year stats  Jason Maxiell
# Have five full-year stats  Jason Richardson
# Have five full-year stats  Jason Terry
# Have five full-year stats  Jason Thompson
# Have five full-year stats  Jason Williams
# Have five full-year stats  Jeff Adrien
# Have five full-year stats  Jeff Foster
# Have five full-year stats  Jeff Teague
# Have five full-year stats  Jeff Withey
# Have five full-year stats  Jelani McCoy
# Have five full-year stats  Jeremy Evans
# Have five full-year stats  Jeremy Lamb
# Have five full-year stats  Jeremy Lin
# Have five full-year stats  Jermaine O'Neal
# Have five full-year stats  Jerome Moiso
# Have five full-year stats  Jerome Williams
# Have five full-year stats  Jerryd Bayless
# Have five full-year stats  Jimmer Fredette
# Have five full-year stats  Jimmy Butler
# Have five full-year stats  Joakim Noah
# Have five full-year stats  Jodie Meeks
# Have five full-year stats  Joe Johnson
# Have five full-year stats  Joel Anthony
# Have five full-year stats  Joel Przybilla
# Have five full-year stats  Joey Graham
# Have five full-year stats  Johan Petro
# Have five full-year stats  John Henson
# Have five full-year stats  John Jenkins
# Have five full-year stats  John Salmons
# Have five full-year stats  John Wall
# Have five full-year stats  John Wallace
# Have five full-year stats  Jon Leuer
# Have five full-year stats  Jonas Valanciunas
# Have five full-year stats  Jonathan Bender
# Have five full-year stats  Jordan Farmar
# Have five full-year stats  Jordan Hamilton
# Have five full-year stats  Jordan Hill
# Have five full-year stats  Jose Calderon
# Have five full-year stats  Josh Howard
# Have five full-year stats  Josh McRoberts
# Have five full-year stats  Josh Powell
# Have five full-year stats  Josh Smith
# Have five full-year stats  Jrue Holiday
# Have five full-year stats  Juan Dixon
# Have five full-year stats  Jumaine Jones
# Have five full-year stats  Kawhi Leonard
# Have five full-year stats  Keith Bogans
# Have five full-year stats  Keith Van Horn
# Have five full-year stats  Kelly Olynyk
# Have five full-year stats  Kelvin Cato
# Have five full-year stats  Kemba Walker
# Have five full-year stats  Kendrick Perkins
# Have five full-year stats  Kenneth Faried
# Have five full-year stats  Kenny Thomas
# Have five full-year stats  Kent Bazemore
# Have five full-year stats  Kentavious Caldwell-Pope
# Have five full-year stats  Kenyon Martin
# Have five full-year stats  Keon Clark
# Have five full-year stats  Kevin Durant
# Have five full-year stats  Kevin Love
# Have five full-year stats  Kevin Martin
# Have five full-year stats  Kevin Ollie
# Have five full-year stats  Kevin Seraphin
# Have five full-year stats  Keyon Dooling
# Have five full-year stats  Khris Middleton
# Have five full-year stats  Kirk Hinrich
# Have five full-year stats  Klay Thompson
# Have five full-year stats  Kobe Bryant
# Have five full-year stats  Kosta Koufos
# Have five full-year stats  Kris Humphries
# Have five full-year stats  Kwame Brown
# Have five full-year stats  Kyle Korver
# Have five full-year stats  Kyle Lowry
# Have five full-year stats  Kyle O'Quinn
# Have five full-year stats  Kyle Singler
# Have five full-year stats  Kyrie Irving
# Have five full-year stats  Kyrylo Fesenko
# Have five full-year stats  LaMarcus Aldridge
# Have five full-year stats  Lamar Odom
# Have five full-year stats  Lance Stephenson
# Have five full-year stats  Lance Thomas
# Have five full-year stats  Landry Fields
# Have five full-year stats  Larry Hughes
# Have five full-year stats  Larry Sanders
# Have five full-year stats  Lavoy Allen
# Have five full-year stats  Lawrence Funderburke
# Have five full-year stats  LeBron James
# Have five full-year stats  Leandro Barbosa
# Have five full-year stats  Lee Nailon
# Have five full-year stats  Leon Powe
# Have five full-year stats  Linton Johnson
# Have five full-year stats  Loren Woods
# Have five full-year stats  Lorenzen Wright
# Have five full-year stats  Lou Amundson
# Have five full-year stats  Lou Williams
# Have five full-year stats  Luc Mbah a Moute
# Have five full-year stats  Luis Scola
# Have five full-year stats  Luke Babbitt
# Have five full-year stats  Luke Ridnour
# Have five full-year stats  Luke Walton
# Have five full-year stats  Luol Deng
# Have five full-year stats  Luther Head
# Have five full-year stats  Malik Allen
# Have five full-year stats  Malik Rose
# Have five full-year stats  Mamadou N'Diaye
# Have five full-year stats  Manu Ginobili
# Have five full-year stats  Marc Gasol
# Have five full-year stats  Marc Jackson
# Have five full-year stats  Marcin Gortat
# Have five full-year stats  Marco Belinelli
# Have five full-year stats  Marcus Banks
# Have five full-year stats  Marcus Camby
# Have five full-year stats  Marcus Fizer
# Have five full-year stats  Marcus Morris
# Have five full-year stats  Marcus Thornton
# Have five full-year stats  Mario Chalmers
# Have five full-year stats  Mark Blount
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-e0dc1971f199> in <module>
#      23     elif seasons_one_thru_four.issubset(playerset) and not (demographic[demographic['name']==player]['year_start'] == 2015).bool():
#      24         fourbutnotfive_but_not_from2015[player] = playerset
# ---> 25     elif 5 in playerset and (demographic[demographic['name']==player]['year_start'] > 1997).bool():
#      26         missing_something_from_years_1thru4_but_has_5[player] = playerset
#      27     else:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in bool(self)
#    1592                              "{0}".format(self.__class__.__name__))
#    1593
# -> 1594         self.__nonzero__()
#    1595
#    1596     def __abs__(self):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1574         raise ValueError("The truth value of a {0} is ambiguous. "
#    1575                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1576                          .format(self.__class__.__name__))
#    1577
#    1578     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# So these are the guys that either need special attention becuase of injuries in years 1-5, or they could be 'zeroed' out in year 5.  Presumably, the GM will know that they aren't giving these guys a 5th year deal.  Like Acie Law, or Anthony Bennett.

# %%
for player, years in fourbutnotfive_but_not_from2015.items():
    print("Player:", player, years)
# Out:
# Player: Aaron Brooks {1, 2, 3, 4, 6, 7, 8, 9, 10, 11}
# Player: Acie Law {1, 2, 3, 4}
# Player: Al Thornton {1, 2, 3, 4}
# Player: Andre Barrett {1, 2, 3, 4}
# Player: Ansu Sesay {1, 2, 3, 4}
# Player: Anthony Bennett {1, 2, 3, 4}
# Player: Archie Goodwin {1, 2, 3, 4}
# Player: Ben Davis {1, 2, 3, 4}
# Player: Carlos Delfino {1, 2, 3, 4, 6, 7, 8, 9}
# Player: Chris Copeland {1, 2, 3, 4}
# Player: DaJuan Summers {1, 2, 3, 4}
# Player: Damion James {1, 2, 3, 4}
# Player: Damone Brown {1, 2, 3, 4}
# Player: Dan Langhi {1, 2, 3, 4}
# Player: Darius Morris {1, 2, 3, 4}
# Player: David Harrison {1, 2, 3, 4}
# Player: Derrick Rose {1, 2, 3, 4, 6, 7, 8, 9, 10}
# Player: Dexter Pittman {1, 2, 3, 4}
# Player: Donte Greene {1, 2, 3, 4}
# Player: Etdrick Bohannon {1, 2, 3, 4}
# Player: Evan Eschmeyer {1, 2, 3, 4}
# Player: Felipe Lopez {1, 2, 3, 4}
# Player: Gerald Green {1, 2, 3, 4, 7, 8, 9, 10, 11, 12, 13}
# Player: Greg Stiemsma {1, 2, 3, 4}
# Player: Henry Sims {1, 2, 3, 4}
# Player: Henry Walker {1, 2, 3, 4, 7}
# Player: Hollis Thompson {1, 2, 3, 4}
# Player: Ike Diogu {1, 2, 3, 4, 6, 7}
# Player: James Anderson {1, 2, 3, 4, 6}
# Player: Jamison Brewer {1, 2, 3, 4}
# Player: Jared Cunningham {1, 2, 3, 4}
# Player: Jeff Green {1, 2, 3, 4, 6, 7, 8, 9, 10, 11}
# Player: Jiri Welsch {1, 2, 3, 4}
# Player: Jordan Crawford {1, 2, 3, 4, 7, 8}
# Player: Josh Boone {1, 2, 3, 4}
# Player: Josh Childress {1, 2, 3, 4, 7, 8, 9, 10}
# Player: Julian Wright {1, 2, 3, 4}
# Player: Kareem Rush {1, 2, 3, 4, 6, 7, 8}
# Player: Kedrick Brown {1, 2, 3, 4}
# Player: Keith McLeod {1, 2, 3, 4}
# Player: Kelenna Azubuike {1, 2, 3, 4, 6}
# Player: Kendall Marshall {1, 2, 3, 4}
# Player: Kerry Kittles {1, 2, 3, 4, 6, 7, 8, 9}
# Player: Kirk Snyder {1, 2, 3, 4}
# Player: Linas Kleiza {1, 2, 3, 4, 6, 7, 8}
# Player: Lonny Baxter {1, 2, 3, 4}
# Player: Luke Jackson {1, 2, 3, 4}
# Player: Malcolm Thomas {1, 2, 3, 4}
# Player: Marcus Williams {1, 2, 3, 4}
# Player: Mardy Collins {1, 2, 3, 4}
# Player: Mario West {1, 2, 3, 4}

# %% [markdown]
# These are the guys we REALLY need to something special with (smooth, or impute data).  There's actually not that many with data for years one through four BUT not five.

# %%
for player, years in fourbutnotfive_but_not_from2015.items():
    if any(x > 5 for x in years):
        print("Player:", player, years)
# Out:
# Player: Aaron Brooks {1, 2, 3, 4, 6, 7, 8, 9, 10, 11}
# Player: Carlos Delfino {1, 2, 3, 4, 6, 7, 8, 9}
# Player: Derrick Rose {1, 2, 3, 4, 6, 7, 8, 9, 10}
# Player: Gerald Green {1, 2, 3, 4, 7, 8, 9, 10, 11, 12, 13}
# Player: Henry Walker {1, 2, 3, 4, 7}
# Player: Ike Diogu {1, 2, 3, 4, 6, 7}
# Player: James Anderson {1, 2, 3, 4, 6}
# Player: Jeff Green {1, 2, 3, 4, 6, 7, 8, 9, 10, 11}
# Player: Jordan Crawford {1, 2, 3, 4, 7, 8}
# Player: Josh Childress {1, 2, 3, 4, 7, 8, 9, 10}
# Player: Kareem Rush {1, 2, 3, 4, 6, 7, 8}
# Player: Kelenna Azubuike {1, 2, 3, 4, 6}
# Player: Kerry Kittles {1, 2, 3, 4, 6, 7, 8, 9}
# Player: Linas Kleiza {1, 2, 3, 4, 6, 7, 8}

# %% [markdown]
# Here are guys that are missing something besides years 5.  Brandon Wright, CDR, Darreell Arthur, Hassan Whiteside, Ian Mahinmi, and similar probably need smoothing.

# %%
for player, years in missing_something_from_years_1thru4_but_has_5.items():
    print(player, years)
# Out:
# Andrew Goudelock {1, 2, 5}
# Blake Ahearn {1, 2, 5}
# Brandan Wright {1, 2, 4, 5, 6, 7, 8, 9, 10, 11}
# Charles Smith (ii) {1, 2, 5, 6, 9}
# Charlie Bell {1, 5, 6, 7, 8, 9, 10}
# Chris Douglas-Roberts {1, 2, 3, 5, 6, 7}
# Corey Benjamin {1, 2, 3, 5}
# Dajuan Wagner {1, 2, 3, 5}
# Daniel Santiago {1, 2, 4, 5}
# Darrell Arthur {1, 2, 3, 5, 6, 7, 8, 9, 10}
# Darryl Watkins {1, 5}
# DerMarr Johnson {1, 2, 4, 5, 6, 7, 8}
# Derrick Dial {1, 2, 3, 5}
# Dwight Buycks {1, 2, 5}
# Earl Barron {1, 2, 3, 5, 6, 7, 8, 10}
# Eddie Gill {1, 2, 4, 5, 6, 8, 9}
# Eddie Griffin {1, 2, 4, 5, 6}
# Elliot Williams {1, 3, 4, 5}
# Ersan Ilyasova {1, 4, 5, 6, 7, 8, 9, 10, 11, 12}
# Garrett Temple {1, 2, 4, 5, 6, 7, 8, 9}
# Hassan Whiteside {1, 2, 5, 6, 7, 8}
# Ian Mahinmi {1, 3, 4, 5, 6, 7, 8, 9, 10, 11}
# Ime Udoka {1, 3, 4, 5, 6, 7, 8}
# Jabari Smith {1, 2, 4, 5}
# James Singleton {1, 2, 4, 5, 7}
# Jason Hart {1, 2, 4, 5, 6, 7, 8, 9, 10}
# Jason Smith {1, 3, 4, 5, 6, 7, 8, 9, 10, 11}
# Jeff Ayres {1, 3, 4, 5, 6, 7}
# Jerome James {1, 4, 5, 6, 7, 8, 9, 10, 11}
# Jonas Jerebko {1, 3, 4, 5, 6, 7, 8, 9}
# Junior Harrington {1, 3, 5}
# Justin Harper {1, 5, 6}
# Justin Holiday {1, 3, 4, 5, 6}
# Kaniel Dickens {1, 2, 5}
# Lorenzo Brown {1, 2, 3, 5}
# Maceo Baston {1, 5, 6, 7}

# %%
SR = seasonalregressor.SeasonalRegressor()

# %%
onlyfouryears = fullstats[fullstats['Seasons_number'] == 4]
onlyfiveyears = fullstats[fullstats['Seasons_number'] == 5]
statstokeep = ['WS',
 'VORP',
 'MP_total',
 'PS/G',
 'FG',
 'MP_pergame',
 'GS',
 'FT',
 '2P',
 'FTA',
 'FGA',
 '2PA',
 'DRB', 'Player']


X, y = SR.create_train_and_predict_X_and_y_from_seasons_4_and_5(onlyfouryears, onlyfiveyears, demographic, statstokeep)

# %%
import importlib
importlib.reload(seasonalregressor)
# Out:
# <module 'source.seasonalregressor' from '/Users/kv/workspace/kv-capstone/NBAwinshare/source/seasonalregressor.py'>
